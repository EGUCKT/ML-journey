# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5
# 0   Atharv  19.0    Mhow     96        72.0         NaN
# 1   Atharv  19.0    Mhow     96        72.0         NaN
# 2     Aman   NaN  Indore     78        85.0         NaN
# 3     Riya  20.0  Bhopal     92        95.0         NaN
# 4    Kunal  18.0  Indore     67        80.0         NaN
# 5    Sneha  19.0  Ujjain     88         NaN         NaN
# 6    Arjun  17.0  Bhopal     74        70.0         NaN
# 7    Priya  20.0  Indore     95        98.0         NaN
# 8     Neha  42.0  Bhopal     81        88.0         NaN
# 9    Rohit  18.0  Ujjain     60        65.0         NaN
# 10    Neha  42.0  Bhopal     81        88.0         NaN
# 11   Vikas  10.0     NaN     73        75.0         NaN
# 12  Anjali  21.0  Ujjain     89        92.0         NaN

# %%
df.shape
# Out:
# (13, 6)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        13 non-null     str
#  1   Age         12 non-null     float64
#  2   City        12 non-null     str
#  3   marks       13 non-null     int64
#  4   Attendance  12 non-null     float64
#  5   Unnamed: 5  0 non-null      float64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 756.0 bytes

# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        13 non-null     str
#  1   Age         12 non-null     float64
#  2   City        12 non-null     str
#  3   marks       13 non-null     int64
#  4   Attendance  12 non-null     float64
#  5   Unnamed: 5  0 non-null      float64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 756.0 bytes

# %%
df.tail()
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5
# 8     Neha  42.0  Bhopal     81        88.0         NaN
# 9    Rohit  18.0  Ujjain     60        65.0         NaN
# 10    Neha  42.0  Bhopal     81        88.0         NaN
# 11   Vikas  10.0     NaN     73        75.0         NaN
# 12  Anjali  21.0  Ujjain     89        92.0         NaN

# %%
df.head()
# Out:
#      Name   Age    City  marks  Attendance  Unnamed: 5
# 0  Atharv  19.0    Mhow     96        72.0         NaN
# 1  Atharv  19.0    Mhow     96        72.0         NaN
# 2    Aman   NaN  Indore     78        85.0         NaN
# 3    Riya  20.0  Bhopal     92        95.0         NaN
# 4   Kunal  18.0  Indore     67        80.0         NaN

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'marks', 'Attendance', 'Unnamed: 5'], dtype='str')

# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5
# 0   Atharv  19.0    Mhow     96        72.0         NaN
# 1   Atharv  19.0    Mhow     96        72.0         NaN
# 2     Aman   NaN  Indore     78        85.0         NaN
# 3     Riya  20.0  Bhopal     92        95.0         NaN
# 4    Kunal  18.0  Indore     67        80.0         NaN
# 5    Sneha  19.0  Ujjain     88         NaN         NaN
# 6    Arjun  17.0  Bhopal     74        70.0         NaN
# 7    Priya  20.0  Indore     95        98.0         NaN
# 8     Neha  42.0  Bhopal     81        88.0         NaN
# 9    Rohit  18.0  Ujjain     60        65.0         NaN
# 10    Neha  42.0  Bhopal     81        88.0         NaN
# 11   Vikas  10.0     NaN     73        75.0         NaN
# 12  Anjali  21.0  Ujjain     89        92.0         NaN

# %%
df.head()
# Out:
#      Name   Age    City  marks  Attendance  Unnamed: 5
# 0  Atharv  19.0    Mhow     96        72.0         NaN
# 1  Atharv  19.0    Mhow     96        72.0         NaN
# 2    Aman   NaN  Indore     78        85.0         NaN
# 3    Riya  20.0  Bhopal     92        95.0         NaN
# 4   Kunal  18.0  Indore     67        80.0         NaN

# %%
df.tail()
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5
# 8     Neha  42.0  Bhopal     81        88.0         NaN
# 9    Rohit  18.0  Ujjain     60        65.0         NaN
# 10    Neha  42.0  Bhopal     81        88.0         NaN
# 11   Vikas  10.0     NaN     73        75.0         NaN
# 12  Anjali  21.0  Ujjain     89        92.0         NaN

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City', 'marks', 'Attendance', 'Unnamed: 5'], dtype='str')

# %%
df.shape
# Out:
# (13, 6)

# %%
df['marks']
# Out:
# 0     96
# 1     96
# 2     78
# 3     92
# 4     67
# 5     88
# 6     74
# 7     95
# 8     81
# 9     60
# 10    81
# 11    73
# 12    89
# Name: marks, dtype: int64

# %%
type(df.marks)
# Out:
# pandas.Series

# %%
type(df['marks'])
# Out:
# pandas.Series

# %%
df.iloc[[0, 3], [1]]
# Out:
#     Age
# 0  19.0
# 3  20.0

# %%
df.loc[[0, 3], ['marks']]
# Out:
#    marks
# 0     96
# 3     92

# %%
import pandas as pd

# %%
df = pd.read_csv('students.csv')

# %%
df['mean'] = df['marks'].sum() / df['marks'].max()

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5       mean
# 0   Atharv  19.0    Mhow     96        72.0         NaN  11.145833
# 1   Atharv  19.0    Mhow     96        72.0         NaN  11.145833
# 2     Aman   NaN  Indore     78        85.0         NaN  11.145833
# 3     Riya  20.0  Bhopal     92        95.0         NaN  11.145833
# 4    Kunal  18.0  Indore     67        80.0         NaN  11.145833
# 5    Sneha  19.0  Ujjain     88         NaN         NaN  11.145833
# 6    Arjun  17.0  Bhopal     74        70.0         NaN  11.145833
# 7    Priya  20.0  Indore     95        98.0         NaN  11.145833
# 8     Neha  42.0  Bhopal     81        88.0         NaN  11.145833
# 9    Rohit  18.0  Ujjain     60        65.0         NaN  11.145833
# 10    Neha  42.0  Bhopal     81        88.0         NaN  11.145833
# 11   Vikas  10.0     NaN     73        75.0         NaN  11.145833
# 12  Anjali  21.0  Ujjain     89        92.0         NaN  11.145833

# %%
df['marks'].mean()
# Out:
# np.float64(82.3076923076923)

# %%
df['marks'].max()
# Out:
# np.int64(96)

# %%
df.loc[df['marks'] > 75, 'Status'] = 'Pass'
df.loc[df['marks'] < 75, 'Status'] = 'Fail'

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5       mean Status
# 0   Atharv  19.0    Mhow     96        72.0         NaN  11.145833   Pass
# 1   Atharv  19.0    Mhow     96        72.0         NaN  11.145833   Pass
# 2     Aman   NaN  Indore     78        85.0         NaN  11.145833   Pass
# 3     Riya  20.0  Bhopal     92        95.0         NaN  11.145833   Pass
# 4    Kunal  18.0  Indore     67        80.0         NaN  11.145833   Fail
# 5    Sneha  19.0  Ujjain     88         NaN         NaN  11.145833   Pass
# 6    Arjun  17.0  Bhopal     74        70.0         NaN  11.145833   Fail
# 7    Priya  20.0  Indore     95        98.0         NaN  11.145833   Pass
# 8     Neha  42.0  Bhopal     81        88.0         NaN  11.145833   Pass
# 9    Rohit  18.0  Ujjain     60        65.0         NaN  11.145833   Fail
# 10    Neha  42.0  Bhopal     81        88.0         NaN  11.145833   Pass
# 11   Vikas  10.0     NaN     73        75.0         NaN  11.145833   Fail
# 12  Anjali  21.0  Ujjain     89        92.0         NaN  11.145833   Pass

# %%
df.shape
# Out:
# (13, 8)

# %%
nulll = df['marks'].isnull()

# %%
nulll
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# Name: marks, dtype: bool

# %%
df[nulll]
# Out:
# Empty DataFrame
# Columns: [Name, Age, City, marks, Attendance, Unnamed: 5, mean, Status]
# Index: []

# %%
df = pd.read_csv('Students.csv')

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5
# 0   Atharv  19.0    Mhow     96        72.0         NaN
# 1   Atharv  19.0    Mhow     96        72.0         NaN
# 2     Aman   NaN  Indore     78        85.0         NaN
# 3     Riya  20.0  Bhopal     92        95.0         NaN
# 4    Kunal  18.0  Indore     67        80.0         NaN
# 5    Sneha  19.0  Ujjain     88         NaN         NaN
# 6    Arjun  17.0  Bhopal     74        70.0         NaN
# 7    Priya  20.0  Indore     95        98.0         NaN
# 8     Neha  42.0  Bhopal     81        88.0         NaN
# 9    Rohit  18.0  Ujjain     60        65.0         NaN
# 10    Neha  42.0  Bhopal     81        88.0         NaN
# 11   Vikas  10.0     NaN     73        75.0         NaN
# 12  Anjali  21.0  Ujjain     89        92.0         NaN

# %%
topper = df['marks'] >= 85
loser = df['marks'] < 75

# %%
df[topper]
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5
# 0   Atharv  19.0    Mhow     96        72.0         NaN
# 1   Atharv  19.0    Mhow     96        72.0         NaN
# 3     Riya  20.0  Bhopal     92        95.0         NaN
# 5    Sneha  19.0  Ujjain     88         NaN         NaN
# 7    Priya  20.0  Indore     95        98.0         NaN
# 12  Anjali  21.0  Ujjain     89        92.0         NaN

# %%
df[loser]
# Out:
#      Name   Age    City  marks  Attendance  Unnamed: 5
# 4   Kunal  18.0  Indore     67        80.0         NaN
# 6   Arjun  17.0  Bhopal     74        70.0         NaN
# 9   Rohit  18.0  Ujjain     60        65.0         NaN
# 11  Vikas  10.0     NaN     73        75.0         NaN

# %%
city = (df['City'] == 'Indore') & (df['Attendance'] >= 75)

# %%
df[city]
# Out:
#     Name   Age    City  marks  Attendance  Unnamed: 5
# 2   Aman   NaN  Indore     78        85.0         NaN
# 4  Kunal  18.0  Indore     67        80.0         NaN
# 7  Priya  20.0  Indore     95        98.0         NaN

# %%
df['marks'].max()
# Out:
# np.int64(96)

# %%
df.groupby("City")["marks"].mean()
# Out:
# City
# Bhopal    82.0
# Indore    80.0
# Mhow      96.0
# Ujjain    79.0
# Name: marks, dtype: float64

# %%
df.loc[df['marks'] > 75, 'Status'] = 'Pass'
df.loc[df['marks'] < 75, 'Status'] = 'Improve'

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5   Status
# 0   Atharv  19.0    Mhow     96        72.0         NaN     Pass
# 1   Atharv  19.0    Mhow     96        72.0         NaN     Pass
# 2     Aman   NaN  Indore     78        85.0         NaN     Pass
# 3     Riya  20.0  Bhopal     92        95.0         NaN     Pass
# 4    Kunal  18.0  Indore     67        80.0         NaN  Improve
# 5    Sneha  19.0  Ujjain     88         NaN         NaN     Pass
# 6    Arjun  17.0  Bhopal     74        70.0         NaN  Improve
# 7    Priya  20.0  Indore     95        98.0         NaN     Pass
# 8     Neha  42.0  Bhopal     81        88.0         NaN     Pass
# 9    Rohit  18.0  Ujjain     60        65.0         NaN  Improve
# 10    Neha  42.0  Bhopal     81        88.0         NaN     Pass
# 11   Vikas  10.0     NaN     73        75.0         NaN  Improve
# 12  Anjali  21.0  Ujjain     89        92.0         NaN     Pass

# %%
df['marks'].mean()
# Out:
# np.float64(82.3076923076923)

# %%
df.isnull().sum()
# Out:
# Name           0
# Age            1
# City           1
# marks          0
# Attendance     1
# Unnamed: 5    13
# Status         0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv('students.csv')
df.loc[df['Age'] >= 20, 'age_group'] = 'Adult'
df.loc[df['Age'] < 20, 'age_group'] = 'Teen'
df.loc[df['marks'] >= 80, 'marks_band'] = 'High'
df.loc[(df['marks'] < 80) & (df['marks'] > 60), 'marks_band'] = 'Medium'
df.loc[df['marks'] <= 60, 'marks_band'] = 'Low'
df.loc[(df['marks_band'] == 'High') & (df['age_group'] == 'Teen'), 'Student_profile'] = 'Brilliant!'
df.loc[(df['marks_band'] == 'High') & (df['age_group'] == 'Adult'), 'Student_profile'] = 'Good'
df.loc[(df['marks_band'] == 'Medium'), 'Student_profile'] = 'Workable'
df.loc[(df['marks_band'] == 'Low'), 'Student_profile'] = 'Loser'

# %%
df.loc[0, 'Student_profile']
# Out:
# 'Brilliant!'

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5 age_group marks_band  \
# 0   Atharv  19.0    Mhow     96        72.0         NaN      Teen       High
# 1   Atharv  19.0    Mhow     96        72.0         NaN      Teen       High
# 2     Aman   NaN  Indore     78        85.0         NaN       NaN     Medium
# 3     Riya  20.0  Bhopal     92        95.0         NaN     Adult       High
# 4    Kunal  18.0  Indore     67        80.0         NaN      Teen     Medium
# 5    Sneha  19.0  Ujjain     88         NaN         NaN      Teen       High
# 6    Arjun  17.0  Bhopal     74        70.0         NaN      Teen     Medium
# 7    Priya  20.0  Indore     95        98.0         NaN     Adult       High
# 8     Neha  42.0  Bhopal     81        88.0         NaN     Adult       High
# 9    Rohit  18.0  Ujjain     60        65.0         NaN      Teen        Low
# 10    Neha  42.0  Bhopal     81        88.0         NaN     Adult       High
# 11   Vikas  10.0     NaN     73        75.0         NaN      Teen     Medium
# 12  Anjali  21.0  Ujjain     89        92.0         NaN     Adult       High
#
#    Student_profile
# 0       Brilliant!
# 1       Brilliant!
# 2         Workable
# 3             Good
# 4         Workable
# 5       Brilliant!
# 6         Workable
# 7             Good
# 8             Good
# 9            Loser
# 10            Good
# 11        Workable
# 12            Good

# %%
gud = df['Student_profile'].str.contains('Brilliant!')

# %%
df.loc[gud, 'Student_profile']
# Out:
# 0    Brilliant!
# 1    Brilliant!
# 5    Brilliant!
# Name: Student_profile, dtype: str

# %%
df.describe()
# Out:
#              Age      marks  Attendance  Unnamed: 5
# count  12.000000  13.000000   12.000000         0.0
# mean   22.083333  82.307692   81.666667         NaN
# std     9.709024  11.607358   10.832051         NaN
# min    10.000000  60.000000   65.000000         NaN
# 25%    18.000000  74.000000   72.000000         NaN
# 50%    19.000000  81.000000   82.500000         NaN
# 75%    20.250000  92.000000   89.000000         NaN
# max    42.000000  96.000000   98.000000         NaN

# %%
df['Student_profile'].value_counts()
# Out:
# Student_profile
# Good          5
# Workable      4
# Brilliant!    3
# Loser         1
# Name: count, dtype: int64

# %%
df['Attendance'].max()
# Out:
# np.float64(98.0)

# %%
hai = df['Attendance'] == 98
df[hai]
# Out:
#     Name   Age    City  marks  Attendance  Unnamed: 5 age_group marks_band  \
# 7  Priya  20.0  Indore     95        98.0         NaN     Adult       High
#
#   Student_profile
# 7            Good

# %%
df['Age'].sort_values()
# Out:
# 11    10.0
# 6     17.0
# 9     18.0
# 4     18.0
# 5     19.0
# 0     19.0
# 1     19.0
# 3     20.0
# 7     20.0
# 12    21.0
# 8     42.0
# 10    42.0
# 2      NaN
# Name: Age, dtype: float64

# %%
df.loc[9]
# Out:
# Name                Rohit
# Age                  18.0
# City               Ujjain
# marks                  60
# Attendance           65.0
# Unnamed: 5            NaN
# age_group            Teen
# marks_band            Low
# Student_profile     Loser
# Name: 9, dtype: object

# %%
df['Age'].isnull().value_counts()
# Out:
# Age
# False    12
# True      1
# Name: count, dtype: int64

# %%
df['Age'].min()
# Out:
# np.float64(10.0)

# %%
df.isnull().sum()
# Out:
# Name                0
# Age                 1
# City                1
# marks               0
# Attendance          1
# Unnamed: 5         13
# age_group           1
# marks_band          0
# Student_profile     0
# dtype: int64

# %%
df['Age'].fillna(df['Age'].median())
# Out:
# 0     19.0
# 1     19.0
# 2     19.0
# 3     20.0
# 4     18.0
# 5     19.0
# 6     17.0
# 7     20.0
# 8     42.0
# 9     18.0
# 10    42.0
# 11    10.0
# 12    21.0
# Name: Age, dtype: float64

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5 age_group marks_band  \
# 0   Atharv  19.0    Mhow     96        72.0         NaN      Teen       High
# 1   Atharv  19.0    Mhow     96        72.0         NaN      Teen       High
# 2     Aman   NaN  Indore     78        85.0         NaN       NaN     Medium
# 3     Riya  20.0  Bhopal     92        95.0         NaN     Adult       High
# 4    Kunal  18.0  Indore     67        80.0         NaN      Teen     Medium
# 5    Sneha  19.0  Ujjain     88         NaN         NaN      Teen       High
# 6    Arjun  17.0  Bhopal     74        70.0         NaN      Teen     Medium
# 7    Priya  20.0  Indore     95        98.0         NaN     Adult       High
# 8     Neha  42.0  Bhopal     81        88.0         NaN     Adult       High
# 9    Rohit  18.0  Ujjain     60        65.0         NaN      Teen        Low
# 10    Neha  42.0  Bhopal     81        88.0         NaN     Adult       High
# 11   Vikas  10.0     NaN     73        75.0         NaN      Teen     Medium
# 12  Anjali  21.0  Ujjain     89        92.0         NaN     Adult       High
#
#    Student_profile
# 0       Brilliant!
# 1       Brilliant!
# 2         Workable
# 3             Good
# 4         Workable
# 5       Brilliant!
# 6         Workable
# 7             Good
# 8             Good
# 9            Loser
# 10            Good
# 11        Workable
# 12            Good

# %%
grp = df.groupby('City')['marks']

# %%
df.groupby('City')['marks'].min()
# Out:
# City
# Bhopal    74
# Indore    67
# Mhow      96
# Ujjain    60
# Name: marks, dtype: int64

# %%
grp.get_group('Ujjain').sort_values()
# Out:
# 9     60
# 5     88
# 12    89
# Name: marks, dtype: int64

# %%
df.loc[7]
# Out:
# Name                Priya
# Age                  20.0
# City               Indore
# marks                  95
# Attendance           98.0
# Unnamed: 5            NaN
# age_group           Adult
# marks_band           High
# Student_profile      Good
# Name: 7, dtype: object

# %%
df.groupby('City')['Name'].count()
# Out:
# City
# Bhopal    4
# Indore    3
# Mhow      2
# Ujjain    3
# Name: Name, dtype: int64

# %%
df.groupby('City')['marks'].describe()
# Out:
#         count  mean        std   min    25%   50%    75%   max
# City
# Bhopal    4.0  82.0   7.438638  74.0  79.25  81.0  83.75  92.0
# Indore    3.0  80.0  14.106736  67.0  72.50  78.0  86.50  95.0
# Mhow      2.0  96.0   0.000000  96.0  96.00  96.0  96.00  96.0
# Ujjain    3.0  79.0  16.462078  60.0  74.00  88.0  88.50  89.0

# %%
df.groupby('City')['marks_band'].value_counts()
# Out:
# City    marks_band
# Bhopal  High          3
#         Medium        1
# Indore  Medium        2
#         High          1
# Mhow    High          2
# Ujjain  High          2
#         Low           1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              Age      marks  Attendance  Unnamed: 5
# count  12.000000  13.000000   12.000000         0.0
# mean   22.083333  82.307692   81.666667         NaN
# std     9.709024  11.607358   10.832051         NaN
# min    10.000000  60.000000   65.000000         NaN
# 25%    18.000000  74.000000   72.000000         NaN
# 50%    19.000000  81.000000   82.500000         NaN
# 75%    20.250000  92.000000   89.000000         NaN
# max    42.000000  96.000000   98.000000         NaN

# %%
df
# Out:
#       Name   Age    City  marks  Attendance  Unnamed: 5 age_group marks_band  \
# 0   Atharv  19.0    Mhow     96        72.0         NaN      Teen       High
# 1   Atharv  19.0    Mhow     96        72.0         NaN      Teen       High
# 2     Aman   NaN  Indore     78        85.0         NaN       NaN     Medium
# 3     Riya  20.0  Bhopal     92        95.0         NaN     Adult       High
# 4    Kunal  18.0  Indore     67        80.0         NaN      Teen     Medium
# 5    Sneha  19.0  Ujjain     88         NaN         NaN      Teen       High
# 6    Arjun  17.0  Bhopal     74        70.0         NaN      Teen     Medium
# 7    Priya  20.0  Indore     95        98.0         NaN     Adult       High
# 8     Neha  42.0  Bhopal     81        88.0         NaN     Adult       High
# 9    Rohit  18.0  Ujjain     60        65.0         NaN      Teen        Low
# 10    Neha  42.0  Bhopal     81        88.0         NaN     Adult       High
# 11   Vikas  10.0     NaN     73        75.0         NaN      Teen     Medium
# 12  Anjali  21.0  Ujjain     89        92.0         NaN     Adult       High
#
#    Student_profile
# 0       Brilliant!
# 1       Brilliant!
# 2         Workable
# 3             Good
# 4         Workable
# 5       Brilliant!
# 6         Workable
# 7             Good
# 8             Good
# 9            Loser
# 10            Good
# 11        Workable
# 12            Good

# %%
df.dropna(axis='columns', how='all', inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df['marks'].sort_values(ascending=False)
# Out:
# 0     96
# 7     95
# 3     92
# 12    89
# 5     88
# 8     81
# 2     78
# 6     74
# 11    73
# 4     67
# 9     60
# Name: marks, dtype: int64

# %%
df
# Out:
#       Name   Age    City  marks  Attendance age_group marks_band  \
# 0   Atharv  19.0    Mhow     96        72.0      Teen       High
# 2     Aman   NaN  Indore     78        85.0       NaN     Medium
# 3     Riya  20.0  Bhopal     92        95.0     Adult       High
# 4    Kunal  18.0  Indore     67        80.0      Teen     Medium
# 5    Sneha  19.0  Ujjain     88         NaN      Teen       High
# 6    Arjun  17.0  Bhopal     74        70.0      Teen     Medium
# 7    Priya  20.0  Indore     95        98.0     Adult       High
# 8     Neha  42.0  Bhopal     81        88.0     Adult       High
# 9    Rohit  18.0  Ujjain     60        65.0      Teen        Low
# 11   Vikas  10.0     NaN     73        75.0      Teen     Medium
# 12  Anjali  21.0  Ujjain     89        92.0     Adult       High
#
#    Student_profile
# 0       Brilliant!
# 2         Workable
# 3             Good
# 4         Workable
# 5       Brilliant!
# 6         Workable
# 7             Good
# 8             Good
# 9            Loser
# 11        Workable
# 12            Good

# %%
import numpy as np

# %%
x = [2, 4, 5, 3, 6]
y = np.array(x)

# %%
print(y)
print(type(y))
# Out:
# [2 4 5 3 6]
# <class 'numpy.ndarray'>

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('student_performance.csv')
df.isnull().sum()
df.shape
# Out:
# (18, 7)

# %%
df.isnull().sum()
# Out:
# name           0
# age            0
# marks          0
# study_hours    0
# city           0
# sleep_hours    0
# attendance     0
# dtype: int64

# %%
df.shape
# Out:
# (18, 7)

# %%
cleandf = df.drop_duplicates()

# %%
cleandf.isnull().sum()
# Out:
# name           0
# age            0
# marks          0
# study_hours    0
# city           0
# sleep_hours    0
# attendance     0
# dtype: int64

# %%
cleandf = df[df["marks"].notnull()]

# %%
df["marks"].notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# Name: marks, dtype: bool

# %%
cleandf.loc[cleandf['marks'] >= 80, 'Performance'] = 'High'
cleandf.loc[(cleandf['marks'] < 80) | (cleandf['marks'] >= 60), 'Performance'] = 'Medium'
cleandf.loc[cleandf['marks'] < 60, 'Performance'] = 'Low'
cleandf['marks'] = cleandf['marks'].fillna(cleandf['marks'].median())

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('student_performance.csv')
df.isnull().sum()
# Out:
# name           0
# age            0
# marks          0
# study_hours    0
# city           0
# sleep_hours    0
# attendance     0
# dtype: int64

# %%
cleandf = df.drop_duplicates()

# %%
cleandf['marks'] = cleandf['marks'].fillna(cleandf['marks'].median())

# %%
cleandf.loc[cleandf['marks'] > 80, 'Performance'] = 'High'
cleandf.loc[(cleandf['marks'] < 80) & (cleandf['marks'] > 60), 'Performance'] = 'Medium'
cleandf.loc[cleandf['marks'] < 60, 'Performance'] = 'Low'

# %%
cleandf['age'] = cleandf['age'].fillna(cleandf['age'].median())
cleandf['study_hours'] = cleandf['study_hours'].fillna(cleandf['study_hours'].median())

# %%
cleandf = cleandf.dropna(subset=['city'])

# %%
cleandf.reset_index(inplace = True)

# %%
cleandf.loc[cleandf['study_hours'] >= 5, 'Study Category'] = 'Serious'
cleandf.loc[cleandf['study_hours'] < 5, 'Study Category'] = 'Casual'

# %%
cleandf.loc[cleandf['Performance'].str.contains('High') & cleandf['Study Category'].str.contains('Serious'), 'Overall'] = 'Good'
cleandf.loc[cleandf['Performance'].str.contains('High') & cleandf['Study Category'].str.contains('Casual'), 'Overall'] = 'Brilliant'
cleandf.loc[cleandf['Performance'].str.contains('Low') & cleandf['Study Category'].str.contains('Serious'), 'Overall'] = 'Gotta focus'
cleandf.loc[cleandf['Performance'].str.contains('Low') & cleandf['Study Category'].str.contains('Casual'), 'Overall'] = 'Study Beta'
cleandf.loc[cleandf['Performance'].str.contains('Medium') & cleandf['Study Category'].str.contains('Serious'), 'Overall'] = 'Improve focus'
cleandf.loc[cleandf['Performance'].str.contains('Medium') & cleandf['Study Category'].str.contains('Casual'), 'Overall'] = 'Study more'

# %%
cleandf
# Out:
#     index          name  age  marks  study_hours       city  sleep_hours  \
# 0       0  Aarav Sharma   19     85            6      Delhi            8
# 1       1   Priya Singh   20     92            8     Mumbai            7
# 2       2   Rohan Gupta   18     74            4  Bangalore            6
# 3       3   Sneha Patel   21     68            5  Bangalore            9
# 4       4    Vikram Das   19     40            3    Kolkata            7
# 5       5   Ananya Iyer   20     88            7    Chennai            8
# 6       7    Kabir Khan   22     95            9      Delhi            8
# 7       8    Meera Nair   19     55            5       Pune            7
# 8       9   Arjun Reddy   20     79            6  Hyderabad            8
# 9      10   Ishan Verma   21     82            5  Ahmedabad            9
# 10     11    Kavita Rao   21     45            2  Bangalore            6
# 11     12   Sahil Mehta   19     90            7     Mumbai            8
# 12     14      Riya Das   18     62            4    Kolkata            7
# 13     15     Amit Shah   20     80            6      Delhi            8
# 14     16   Pooja Joshi   19     71            3       Pune            7
#
#     attendance Performance Study Category        Overall
# 0           90        High        Serious           Good
# 1           85        High        Serious           Good
# 2           80      Medium         Casual     Study more
# 3           75      Medium        Serious  Improve focus
# 4           70         Low         Casual     Study Beta
# 5           95        High        Serious           Good
# 6           90        High        Serious           Good
# 7           85         Low        Serious    Gotta focus
# 8           85      Medium        Serious  Improve focus
# 9           80        High        Serious           Good
# 10          75         Low         Casual     Study Beta
# 11          90        High        Serious           Good
# 12          75      Medium         Casual     Study more
# 13          90         NaN        Serious            NaN
# 14          80      Medium         Casual     Study more

# %%
cleandf.groupby('city')['marks'].mean()
# Out:
# city
# Ahmedabad    82.000000
# Bangalore    62.333333
# Chennai      88.000000
# Delhi        86.666667
# Hyderabad    79.000000
# Kolkata      51.000000
# Mumbai       91.000000
# Pune         63.000000
# Name: marks, dtype: float64

# %%
cleandf.groupby('Performance')['marks'].mean()
# Out:
# Performance
# High      88.666667
# Low       46.666667
# Medium    70.800000
# Name: marks, dtype: float64

# %%
array = cleandf['marks'].astype(float).to_numpy()

# %%
print(array)
# Out:
# [85. 92. 74. 68. 40. 88. 95. 55. 79. 82. 45. 90. 62. 80. 71.]

# %%
array.mean()
# Out:
# np.float64(73.73333333333333)

# %%
array.max()
# Out:
# np.float64(95.0)

# %%
array.min()
# Out:
# np.float64(40.0)

# %%
gudarray = 1/array.max() * array

# %%
print(gudarray)
# Out:
# [0.89473684 0.96842105 0.77894737 0.71578947 0.42105263 0.92631579
#  1.         0.57894737 0.83157895 0.86315789 0.47368421 0.94736842
#  0.65263158 0.84210526 0.74736842]

# %%
cleandf['marks'].sort_values(ascending = False).head()
# Out:
# 6     95
# 1     92
# 11    90
# 5     88
# 0     85
# Name: marks, dtype: int64

# %%
df[["study_hours", "marks"]].corr()
# Out:
#              study_hours     marks
# study_hours     1.000000  0.852321
# marks           0.852321  1.000000
